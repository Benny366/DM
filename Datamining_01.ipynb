# %% [markdown]
# <a href="https://colab.research.google.com/github/Benny366/DM/blob/main/Datamining_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('aadd.csv')

# %%
print("missing values before imputation: ")
# Out:
# missing values before imputation:

# %%
print(data.isnull().sum())
# Out:
# Gender            12
# Married          140
# Age               13
# Graduat           78
# Profession       124
# Experience       828
# SpendingScore      0
# FamilySize       335
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mode(), inplace=True)

# %%
print(data.isnull().sum)
# Out:
# <bound method DataFrame.sum of       Gender  Married    Age  Graduat  Profession  Experience  SpendingScore  \
# 0      False    False  False    False       False       False          False
# 1       True    False  False    False       False       False          False
# 2      False    False  False    False       False       False          False
# 3      False    False   True    False       False       False          False
# 4       True    False  False    False       False        True          False
# ...      ...      ...    ...      ...         ...         ...            ...
# 8063   False    False  False    False        True       False          False
# 8064   False    False  False    False       False       False          False
# 8065   False    False  False    False       False       False          False
# 8066   False    False  False    False       False       False          False
# 8067   False    False  False    False       False       False          False
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')
data['FamilySize'] = pd.to_numeric(data['FamilySize'], errors='coerce')

# %%
columns_to_normalize = ['Age', 'FamilySize']
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# %%
data[['Age', 'FamilySize']].head()
# Out:
#         Age  FamilySize
# 0  0.056338         NaN
# 1  0.281690       0.250
# 2       NaN       0.000
# 3       NaN       0.125
# 4  0.309859       0.625

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# %%
data[['Age', 'FamilySize']].head()
# Out:
#         Age  FamilySize
# 0 -1.284702         NaN
# 1 -0.327246    0.097969
# 2       NaN   -1.208062
# 3       NaN   -0.555046
# 4 -0.207564    2.057015
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['FamilySize'].plot(kind='hist', bins=20, title='FamilySize')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
data.describe()
# Out:
#                 Age    FamilySize
# count  8.054000e+03  7.732000e+03
# mean  -7.057787e-17 -8.684207e-17
# std    1.000062e+00  1.000065e+00
# min   -1.524065e+00 -1.208062e+00
# 25%   -8.059736e-01 -5.550462e-01
# 50%   -2.075637e-01  9.796920e-02
# 75%    5.703692e-01  7.509846e-01
# max    2.724645e+00  4.016062e+00
